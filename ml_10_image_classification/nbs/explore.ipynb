# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ### Test image

# %%
# Generate a randon numpy array
rnd_image = np.random.randint(0, 256, (256, 256))

# %%
# Plot
plt.figure(figsize=(7, 7))
plt.imshow(rnd_image, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# ### Check one image from dataset

# %%
img = Image.open('../data/train_png/1.2.276.0.7230010.3.1.4.8323329.13666.1517875247.117800.png')
type(img)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
img.size, img.info
# Out:
# ((1024, 1024), {})

# %%
# Plot
plt.figure(figsize=(7, 7))
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# ### Check train csv file

# %%
# Check image segmentation dataset
df_train = pd.read_csv("../data/train.csv")
df_train.shape
# Out:
# (10675, 3)

# %%
df_train.head()
# Out:
#                                              ImageId  \
# 0  1.2.276.0.7230010.3.1.4.8323329.13666.15178752...
# 1  1.2.276.0.7230010.3.1.4.8323329.11028.15178752...
# 2  1.2.276.0.7230010.3.1.4.8323329.10366.15178752...
# 3  1.2.276.0.7230010.3.1.4.8323329.10016.15178752...
# 4  1.2.276.0.7230010.3.1.4.8323329.11444.15178752...
#
#                                        EncodedPixels  target
# 0  557374 2 1015 8 1009 14 1002 20 997 26 990 32 ...       1
# 1                                                 -1       0
# 2  514175 10 1008 29 994 30 993 32 991 33 990 34 ...       1
# 3  592184 33 976 58 956 73 941 88 926 102 917 109...       1
# 4                                                 -1       0

# %%
df_train.columns
# Out:
# Index(['ImageId', 'EncodedPixels', 'target'], dtype='object')

# %%
df_train.EncodedPixels
# Out:
# 0        557374 2 1015 8 1009 14 1002 20 997 26 990 32 ...
# 1                                                       -1
# 2        514175 10 1008 29 994 30 993 32 991 33 990 34 ...
# 3        592184 33 976 58 956 73 941 88 926 102 917 109...
# 4                                                       -1
#                                ...
# 10670                                                   -1
# 10671    426110 2 1021 3 1020 4 1019 4 1019 5 1018 5 10...
# 10672    610404 7 1014 11 1012 13 1010 14 1009 16 1007 ...
# 10673                                                   -1
# 10674                                                   -1
# Name: EncodedPixels, Length: 10675, dtype: object
